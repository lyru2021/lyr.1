# %% [markdown]
# <h1>实验3 基于第三代蜜网的VNet网络攻防实验环境构建<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#实验目的" data-toc-modified-id="实验目的-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>实验目的</a></span></li><li><span><a href="#实验内容" data-toc-modified-id="实验内容-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>实验内容</a></span></li><li><span><a href="#实验环境" data-toc-modified-id="实验环境-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>实验环境</a></span></li><li><span><a href="#网络拓扑结构图" data-toc-modified-id="网络拓扑结构图-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>网络拓扑结构图</a></span></li><li><span><a href="#软硬件需求" data-toc-modified-id="软硬件需求-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>软硬件需求</a></span></li><li><span><a href="#背景知识" data-toc-modified-id="背景知识-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>背景知识</a></span></li><li><span><a href="#虚拟蜜网的构建" data-toc-modified-id="虚拟蜜网的构建-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>虚拟蜜网的构建</a></span><ul class="toc-item"><li><span><a href="#虚拟网卡配置" data-toc-modified-id="虚拟网卡配置-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>虚拟网卡配置</a></span></li><li><span><a href="#攻击机配置" data-toc-modified-id="攻击机配置-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>攻击机配置</a></span><ul class="toc-item"><li><span><a href="#Kali_Linux" data-toc-modified-id="Kali_Linux-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Kali_Linux</a></span></li><li><span><a href="#WinXPattacker" data-toc-modified-id="WinXPattacker-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>WinXPattacker</a></span></li><li><span><a href="#SEEDUbuntu" data-toc-modified-id="SEEDUbuntu-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>SEEDUbuntu</a></span></li></ul></li><li><span><a href="#靶机配置" data-toc-modified-id="靶机配置-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>靶机配置</a></span><ul class="toc-item"><li><span><a href="#Metasploitable_xpsp1" data-toc-modified-id="Metasploitable_xpsp1-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Metasploitable_xpsp1</a></span></li><li><span><a href="#Win2kServer_SP0" data-toc-modified-id="Win2kServer_SP0-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Win2kServer_SP0</a></span></li><li><span><a href="#Metasploitable_Win2K3" data-toc-modified-id="Metasploitable_Win2K3-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Metasploitable_Win2K3</a></span></li><li><span><a href="#Linux-Metasploitable-v1.0" data-toc-modified-id="Linux-Metasploitable-v1.0-7.3.4"><span class="toc-item-num">7.3.4&nbsp;&nbsp;</span>Linux Metasploitable v1.0</a></span></li><li><span><a href="#Linux-Metasploitable-v2.0" data-toc-modified-id="Linux-Metasploitable-v2.0-7.3.5"><span class="toc-item-num">7.3.5&nbsp;&nbsp;</span>Linux Metasploitable v2.0</a></span></li></ul></li><li><span><a href="#蜜网网关配置" data-toc-modified-id="蜜网网关配置-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>蜜网网关配置</a></span><ul class="toc-item"><li><span><a href="#安装蜜网网关虚拟机" data-toc-modified-id="安装蜜网网关虚拟机-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>安装蜜网网关虚拟机</a></span></li><li><span><a href="#安装蜜网网关软件" data-toc-modified-id="安装蜜网网关软件-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>安装蜜网网关软件</a></span></li><li><span><a href="#配置蜜网网关" data-toc-modified-id="配置蜜网网关-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>配置蜜网网关</a></span></li><li><span><a href="#蜜罐信息配置" data-toc-modified-id="蜜罐信息配置-7.4.4"><span class="toc-item-num">7.4.4&nbsp;&nbsp;</span>蜜罐信息配置</a></span></li><li><span><a href="#蜜网网关管理配置" data-toc-modified-id="蜜网网关管理配置-7.4.5"><span class="toc-item-num">7.4.5&nbsp;&nbsp;</span>蜜网网关管理配置</a></span></li><li><span><a href="#Sebek-服务器端配置" data-toc-modified-id="Sebek-服务器端配置-7.4.6"><span class="toc-item-num">7.4.6&nbsp;&nbsp;</span>Sebek 服务器端配置</a></span></li></ul></li></ul></li><li><span><a href="#环境测试" data-toc-modified-id="环境测试-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>环境测试</a></span><ul class="toc-item"><li><span><a href="#测试蜜网网关的远程管理" data-toc-modified-id="测试蜜网网关的远程管理-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>测试蜜网网关的远程管理</a></span></li><li><span><a href="#连通性测试" data-toc-modified-id="连通性测试-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>连通性测试</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 实验目的

# %% [markdown]
# 虚拟机的搭建、VMWare Workstation软件的使用、使用虚拟机系统在本地构建由多台主机（包括攻击机和靶机、蜜网网关）、多个路由器组成的网络攻防实践环境、配置主机的IP地址并测试其连通性等。

# %% [markdown]
# # 实验内容

# %% [markdown]
# 1. 利用提供的虚拟机镜像和VMWare Workstations软件，在自己的笔记本电脑或者PC上部署一套个人版网络攻防实践环境，至少包括一台攻击机、一台靶机、SEED虚拟机和蜜网网关
# 2. 并进行网络连通性测试，确保各个虚拟机能够正常联通。
# 3. 撰写详细实验报告，细致说明安装和配置过程（截图）、过程说明、发现问题和解决问题过程，以及最后测试结果。

# %% [markdown]
# # 实验环境

# %% [markdown]
# 网络攻防环境的搭建是网络攻防实践的基础，在有限的资源环境下，搭建一个属于自己的网络攻防实验环境，可以进行可控、可重复的网络攻防技术实验与实践活动，以便进一步深入理解相关的基础知识与底层机制、攻防技术方法，并掌握攻防技术技能。网络攻防环境需要包含以下几个部分：

# %% [markdown]
# 本次网络攻防实验环境需要如下组成部分
# 1. 靶机：靶机及被攻击的机器，内置系统和应用程序安全漏洞，并作为目标的主机。本次实验选用的靶机为Win2kServer_SP0_target和Metasploitable_ubuntu。
# 2. 攻击机：安装了专用的攻击软件，用于发起网络攻击的主机。本次实验选用的攻击机为Kali、WinXPattacker和SEEDUbuntu。
# 3. 攻击检测、分析与防御平台：最佳位置是靶机的网关，可以基于Linux 操作系统构。建网关主机，并通过集成各种软件使其具备网络攻击检测、分析与防御的功能;此外靶机上也通过自带或附加的工具进行系统安全日志分析。蜜网（honeynet）是一个网路系统，而并非某台单一主机，这一网路系统是隐藏在防火墙后面的，所有进出的资料都受到监控、捕获及控制。虽然honeynet看起来是个网络，但是实际上honeynet在一个服务器上。实验中使用的网关为HoneyWall-蜜网网关ROO。
# 4. 网络连接：通过网络将靶机、攻击机和具备检测分析防御功能的网关进行连接。网络攻防环境使用VMware进行搭建。

# %% [markdown]
# 实践要用到的材料：

# %% [markdown]
# 1. VMWare Workstation
# 2. 攻击机和靶机的虚拟机镜像
# 3. Kali-Linux
# 4. 蜜网网关的安装镜像

# %% [markdown]
# 重要提醒：

# %% [raw]
# 攻击机镜像
# BT5R3  root/toor
# Windows XP Attacker administrator/mima1234
#
# SEEDUbuntu9_August_2010
# 1. User ID: root,	Password: seedubuntu.
# Note:	不允许直接root登录，需普通账号登录，然后使用su提升至root
# 2. User ID: seed,	Password: dees
#
# 靶机镜像
#
# Win2KS Metasploitable administrator/mima1234
# VM_Metasploitable_xpsp1  administrator/frank
#
# VM_Metasploitable_ubuntu（Linux Metasploitable v1.0）msfadmin/msfadmin
# metasploitable-linux-2.0.0（Linux Metasploitable v2.0） msfadmin/msfadmin
#
# ROO安装镜像
# 首次登录密码：
# 1. roo/honey
# 2. root/honey,  必须普通账号登录，然后使用su -提升至root

# %% [markdown]
# # 网络拓扑结构图

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Win2kServer_SP0_target和Metasploitable_ubuntu使用192.168.13.128/25作为靶机网段，并使用host-only模式的VMnet1虚拟网卡；
# - Kali、WinXPattacker和SEEDUbuntu使用192.168.13.0/25作为攻击网段，并设置连入相应的NAT模式的VMnet8；
# - 蜜网网关HoneyWall的eth0链接攻击机网段，eth1连接靶机网段，eth2接口也连接入VMnet8网段，设置其管理IP为192.168.13.8，宿主可以通过VMnet8虚拟网卡访问蜜网网关，进行数据分析和蜜网网关管理。

# %% [markdown]
# # 软硬件需求

# %% [markdown]
# 基于Win32平台构建虚拟蜜网的硬件配置建议如下：
# - 至少 P4 CPU，建议 2.0G Hz 以上
# - 至少 1G 内存，建议 2G 以上
# - 至少 20G 硬盘，建议 40G 以上
#
# 软件配置包括：
#
# 宿主主机：
# - 操作系统：Win2K/WinXP，本文档基于 Windows XP SP2
# - VMware Workstation for Win32 ， 本 文 档 使 用
# - VMware Workstation Pro
#
# 蜜网网关虚拟机：
# - Roo Honeywall CDROM v1.4
#
# 攻击机和靶机：
# - WinXPattacker ，Kali Linux和SEEDUbuntu 作为攻击机
# - Win2kServer_SP0_target 作为靶机

# %% [markdown]
# # 背景知识

# %% [markdown]
# - 蜜网与蜜网网关：蜜网（Honeynet）是在蜜罐技术上逐步发展起来的，又可称为诱捕网络。通过使用蜜网，捕获黑客的攻击信息，以便于防御者和研究人员用于技术研究、采取针对性的防御措施。蜜墙（Honeywall），是蜜网的网关，也就是出入蜜网的所有数据的必经关卡。本实验中所采用的roo-1.4，是一款基于linux的开源蜜网网关系统。
# - 攻击机：本实验采用的攻击机包括WinXPattacker，Kali Linux和SEEDUbuntu。其中，WinXPattacker和Kali Linux包含了网络监听工具wireshark、渗透工具metasploit、反汇编工具、反编译工具、密码工具等，与前者相比，Kali Linux更是包含了数百款最新的攻击工具，经常被视为“黑客”的首选操作系统。SEEDUbuntu是Seed Labs定制的一款专用于计算机信息安全研究的Ubuntu操作系统（官网：SEED Project (seedsecuritylabs.org)）。
# - 靶机：Win2kServer_SP0_target 作为靶机,是网络攻击者攻击的目标，这些靶机通常会采取相应的安全防护措施（如入侵检测、防火墙等）。
# - 几个常见的工具介绍：
#     - nmap：一款网络扫描和主机检测的非常有用的工具不仅仅局限于收集信息和枚举，还可以用来作为一个漏洞探测器或安全扫描器。
#     - metasploit：是一款开源安全漏洞利用和测试工具，集成了各种平台上常见的溢出漏洞和流行的shellcode，并持续保持更新，涵盖了渗透测试中的全过程，你可以在这个框架下利用现有的Payload进行一系列的渗透测试。
#     - wireshark：是一个网络封包分析软件，功能是截取网络封包，并尽可能显示出最为详细的网络封包资料。wireshark可以被用来学习网络协议、检测网络和信息问题、截取敏感信息等。
#     - WebScarab：一个用来分析使用HTTP和HTTPS协议的应用程序框架，让使用者可以掌握某种基于HTTP(S)程序的运作过程；可以用它来调试程序中较难处理的bug，也可以帮助安全专家发现潜在的程序漏洞。

# %% [markdown]
# # 虚拟蜜网的构建

# %% [markdown]
# ## 虚拟网卡配置

# %% [markdown]
# 打开VMware，在菜单栏点击编辑->虚拟网络编辑器，进行VMnet1和VMnet8的网段配置（点击“更改设置”进入设置页面）：

# %% [markdown]
# 1. 选择 VMnet1，设置如下

# %% [markdown]
# 将VMnet1的子网IP修改为192.168.13.128，相应的子网掩码为255.255.255.128

# %% [markdown]
# ![1676029525667.png](attachment:1676029525667.png)

# %% [raw]
# 注意：一定要勾选红框内容

# %% [markdown]
# 2. 选择 VMnet8，设置如下:

# %% [markdown]
# 将VMnet8的子网IP修改为192.168.13.0，相应的子网掩码为255.255.255.128，在NAT设置中将网关设置为192.168.13.2，在DHCP设置中将子网IP分配范围设置为192.168.13.64~192.168.13.120，当主机连接进VMnet8网段时，则会自动为其分配一个IP地址（需要开启VMware DHCP Service服务）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 点击图中的 NAT Settings，设置如下：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 点击图中的 DHCP Settings，设置如下：

# %% [raw]
# （注意：为了留一些 IP 给靶机，在这里 End IP address 没有设为 192.168.13.126）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 攻击机配置

# %% [markdown]
# ### Kali_Linux

# %% [markdown]
# 打开Kali虚拟机（之前安装过，所以直接使用以前的Kali进行环境配置，如果没有的话需要自己使用kali镜像进行安装），进行虚拟机设置->网络适配器->网络连接->自定义（VMnet8（NAT 模式））。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 注意：保证虚拟网卡VMware8和虚拟机的IP地址处于同一网段，请将VMnet8的IP地址设置为自动获取。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 开启Kali，查看分配的IP地址（如果不开启DHCP服务，会显示无网络连接）：

# %% [raw]
# root@kali:~# ifconfig
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet6 fe80::20c:29ff:fea0:dd7d  prefixlen 64  scopeid 0x20<link>
#         ether 00:0c:29:a0:dd:7d  txqueuelen 1000  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 20  bytes 2904 (2.8 KiB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 16  bytes 960 (960.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 16  bytes 960 (960.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# root@kali:~#

# %% [markdown]
# （如果开启DHCP服务，会显示网络连接）：

# %% [raw]
# root@kali:~# ifconfig
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 192.168.13.64  netmask 255.255.255.128  broadcast 192.168.13.127
#         inet6 fe80::20c:29ff:fea0:dd7d  prefixlen 64  scopeid 0x20<link>
#         ether 00:0c:29:a0:dd:7d  txqueuelen 1000  (Ethernet)
#         RX packets 10  bytes 1530 (1.4 KiB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 30  bytes 3066 (2.9 KiB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 18  bytes 1038 (1.0 KiB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 18  bytes 1038 (1.0 KiB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# root@kali:~# ping www.baidu.com
# PING www.a.shifen.com (220.181.38.150) 56(84) bytes of data.
# 64 bytes from 220.181.38.150 (220.181.38.150): icmp_seq=1 ttl=128 time=4.83 ms
# 64 bytes from 220.181.38.150 (220.181.38.150): icmp_seq=2 ttl=128 time=5.45 ms
# 64 bytes from 220.181.38.150 (220.181.38.150): icmp_seq=3 ttl=128 time=5.06 ms
# 64 bytes from 220.181.38.150 (220.181.38.150): icmp_seq=4 ttl=128 time=5.75 ms
# ^C
# --- www.a.shifen.com ping statistics ---
# 4 packets transmitted, 4 received, 0% packet loss, time 3010ms
# rtt min/avg/max/mdev = 4.829/5.269/5.745/0.352 ms

# %% [markdown]
# 下面配置Kali的IP地址为192.168.13.5 ，如图所示：

# %% [markdown]
# 1. 临时配置，此方式重启后,配置消失

# %% [raw]
# 配置网卡的IP地址
#
# 　　ifconfig eth0 192.168.13.5 netmask 255.255.255.128
#
# 配置网关：
#
#    route add default gw 192.168.13.2

# %% [raw]
# root@kali:~# ifconfig eth0 192.168.13.5 netmask 255.255.255.128
# root@kali:~# route add default gw 192.168.13.2
# root@kali:~# ifconfig
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 192.168.13.5  netmask 255.255.255.128  broadcast 192.168.13.127
#         inet6 fe80::20c:29ff:fea0:dd7d  prefixlen 64  scopeid 0x20<link>
#         ether 00:0c:29:a0:dd:7d  txqueuelen 1000  (Ethernet)
#         RX packets 18  bytes 2433 (2.3 KiB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 40  bytes 3891 (3.7 KiB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 18  bytes 1038 (1.0 KiB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 18  bytes 1038 (1.0 KiB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# root@kali:~# ping www.baidu.com
# PING www.a.shifen.com (220.181.38.149) 56(84) bytes of data.
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=1 ttl=128 time=5.04 ms
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=2 ttl=128 time=5.16 ms
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=3 ttl=128 time=5.59 ms
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=4 ttl=128 time=5.18 ms
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=5 ttl=128 time=5.35 ms
# 64 bytes from 220.181.38.149 (220.181.38.149): icmp_seq=6 ttl=128 time=5.33 ms
# ^C
# --- www.a.shifen.com ping statistics ---
# 6 packets transmitted, 6 received, 0% packet loss, time 5025ms
# rtt min/avg/max/mdev = 5.041/5.272/5.590/0.176 ms
# root@kali:~#

# %% [markdown]
# 2. 永久配置静态IP

# %% [raw]
# vim /etc/network/interfaces

# %% [markdown]
# 原内容：

# %% [raw]
# auto lo
#
# iface lo inet loopback
# auto eth0
# iface eth0 inet dhcp

# %% [markdown]
# 修改为：

# %% [raw]
# # This file describes the network interfaces available on your system
# # and how to activate them. For more information, see interfaces(5).
#
# source /etc/network/interfaces.d/*
#
# # The loopback network interface
# auto lo
# iface lo inet loopback
#
# auto eth0
# iface eth0 inet static
# address 192.168.13.5
# netmask 255.255.255.128
# gateway 192.168.13.2

# %% [markdown]
# 注意，静态IP地址必须在DHCP范围内。

# %% [markdown]
# 保存后，重新启动：

# %% [raw]
# /etc/init.d/networking restart

# %% [markdown]
# 配置好静态IP地址后,将其保存并退出,然后在终端重启网络,命令为“/etc/init.d/networking restart",重启网络成功后, Kali Linux 操作系统的静态IP地址配置完成。

# %% [markdown]
# 之后就可以ping一下物理机和外网了~

# %% [markdown]
# ### WinXPattacker

# %% [markdown]
# WinXPAttacker虚拟机镜像文件为VM_WinXPattacker.rar

# %% [markdown]
# 1.下载并解压 WinXPattacker 的 rar 镜像到 E:\VM_Network_Security\WinXPAttacker（根据自己情况选择）
# 2. File --> Open，选择你的解压目录，选择相应 vmx 文件
# 3． 配置攻击机虚拟机的硬件
#
# 鼠标选择 WinXPattacker 的选项卡，菜单中选择 VM -->Settings，Hardware 选项卡中选择点击 Memory，在右侧设置合适大小（注意这项在虚拟机开启时不可设置，可先将该虚拟机 power off，设置好之后，再 power on）

# %% [markdown]
# 注意，请将CD/DVD（IDE） 启动时连接 断开，否则会死机。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 打开准备好的WinXPAttacker虚拟机，同Kali一样，首先配置网络适配器，将网络连接选为自定义-VMnet8（NAT 模式）：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 之后开启该虚拟机，设置并查看IP地址为192.168.13.4：

# %% [raw]
# 备注：Windows XP Attacker 用户名/密码 administrator/mima1234

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DHCP 动态分配给攻击机虚拟机的 IP 地址为 192.168.13.4

# %% [markdown]
# ### SEEDUbuntu

# %% [markdown]
# 资料中给的SEEDUbuntu为磁盘文件SEEDUbuntu9_August_2010.tar.gz，将文件解压到 虚拟盘存放位置，然后虚拟机打开，如图所示：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CD/DVD(IDE)不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 网络适配器选择VMnet8:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 启动时，点击"我已复制该虚拟机"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# SEEDUbuntu9_August_2010
# 1. User ID: root,	Password: seedubuntu.
# Note:	不允许直接root登录，需普通账号登录，然后使用su提升至root
# 2. User ID: seed,	Passeedssword: dees

# %% [markdown]
# 以普通用户登录：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 查看IP地址：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 查看到IP地址为192.168.13.3，连接外网正常。

# %% [markdown]
# 也可以配置为静态IP：

# %% [raw]
# 配置网卡的IP地址
#
# ifconfig eth6 192.168.13.3 netmask 255.255.255.128
#
# 配置网关：
#
# route add default gw 192.168.13.2

# %% [markdown]
# ## 靶机配置

# %% [markdown]
# ### Metasploitable_xpsp1

# %% [markdown]
# 1. 下载并解压 VM_Metasploitable_xpsp1.rar 的 rar 镜像到某一目录(如：E:\VM_Network_Security\Metasploitable_xpsp1)

# %% [markdown]
# 2. File --> Open，选择你的解压目录，选择相应 vmx 文件

# %% [markdown]
# 3. 配置靶机虚拟机的硬件

# %% [markdown]
# 鼠标选择 Win2kServer_SP0_target 的选项卡，菜单中选择 VM -->Settings，Hardware 选项卡中选择点击 Memory，在右侧设置合适大小（注意这项在虚拟机开启时不可设置，可先将该虚拟机 power off，设置好之后，再 power on）

# %% [markdown]
# 软盘不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CD/DVD(IDE)不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 内存根据需要配置：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 网络适配器选择VMnet1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 打开准备好的Win2kServer_SP0_target虚拟机，点击开始->控制面板->网络连接->本地连接->属性->Internet协议（TCP/IP），修改IP地址，配置如图所示：

# %% [raw]
# 备注：登录用户名/密码 administrator/frank

# %% [markdown]
# 配置IP地址：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 配置好之后，使用ipconfig命令查看配置结果，如图所示，虚拟机IP地址配置成功：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Win2kServer_SP0

# %% [markdown]
# 1. 下载并解压 Win2kServer_SP0_target 的 rar 镜像到某一目录(如：E:\VM_Network_Security\Win2kServer_SP0_target)

# %% [markdown]
# 2. File --> Open，选择你的解压目录，选择相应 vmx 文件

# %% [markdown]
# 3. 配置靶机虚拟机的硬件

# %% [markdown]
# 鼠标选择 Win2kServer_SP0_target 的选项卡，菜单中选择 VM -->Settings，Hardware 选项卡中选择点击 Memory，在右侧设置合适大小（注意这项在虚拟机开启时不可设置，可先将该虚拟机 power off，设置好之后，再 power on）

# %% [markdown]
# 软盘不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CD/DVD(IDE)不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 内存根据需要配置：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 网络适配器选择VMnet1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 打开准备好的Win2kServer_SP0_target虚拟机，点击开始->控制面板->网络连接->本地连接->属性->Internet协议（TCP/IP），修改IP地址，配置如图所示：

# %% [raw]
# 备注：登录用户名/密码 administrator/mima1234

# %% [markdown]
# 配置IP地址：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 配置好之后，使用ipconfig命令查看配置结果，如图所示，虚拟机IP地址配置成功：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Metasploitable_Win2K3

# %% [markdown]
# 1. 下载并解压 Win2K3 Metasploitable.rar 的 rar 镜像到某一目录(如：E:\VM_Network_Security\Metasploitable_Win2K3)

# %% [markdown]
# 2. File --> Open，选择你的解压目录，选择相应 vmx 文件

# %% [markdown]
# 3. 配置靶机虚拟机的硬件

# %% [markdown]
# 鼠标选择 Win2K3 Metasploitablet 的选项卡，菜单中选择 VM -->Settings，Hardware 选项卡中选择点击 Memory，在右侧设置合适大小（注意这项在虚拟机开启时不可设置，可先将该虚拟机 power off，设置好之后，再 power on）

# %% [markdown]
# 软盘不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# CD/DVD(IDE)不要勾选“启动时连接”：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 内存根据需要配置：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 网络适配器选择VMnet1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 打开准备好的Win2K3 Metasploitablett虚拟机，点击开始->控制面板->网络连接->本地连接->属性->Internet协议（TCP/IP），修改IP地址，配置如图所示：

# %% [markdown]
# 配置IP地址：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 配置好之后，使用ipconfig命令查看配置结果，如图所示，虚拟机IP地址配置成功：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linux Metasploitable v1.0

# %% [markdown]
# 打开准备好的Metasploitable_ubuntu虚拟机，并使用用户名和密码进行登录：

# %% [markdown]
# 虚拟机设置同上

# %% [raw]
# 用户名/密码 msfadmin/msfadmin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 在命令行界面使用 `sudo vim /etc/rc.local` 命令进行IP地址配置，在文件中添加 `ifconfig eth0 192.168.13.133 netmask 255.255.255.128 `，保存退出。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 重启虚拟机，使用ifconfig查看IP地址，如图所示，配置成功：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linux Metasploitable v2.0

# %% [markdown]
# 打开准备好的 metasploitable-linux-2.0.0.zip 虚拟机，并使用用户名和密码进行登录：

# %% [markdown]
# 虚拟机设置同上

# %% [raw]
# 用户名/密码 msfadmin/msfadmin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 在命令行界面使用 `sudo vim /etc/rc.local` 命令进行IP地址配置，在文件中添加 `ifconfig eth0 192.168.13.134 netmask 255.255.255.128 `，保存退出。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 重启虚拟机，使用ifconfig查看IP地址，如图所示，配置成功：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 蜜网网关配置

# %% [markdown]
# 我们如果要在VM上搭建蜜网系统，蜜网网关的配置将是至关重要的。
#
# 即如何正确的安装roo-1.4.hw-20090425114542.iso，其实roo-1.4.hw-20090425114542.iso已经配置好了，不是要安装，而是需要正确的挂载，否则，roo-1.4.hw-20090425114542.iso中的配置将会被删除。

# %% [markdown]
# ### 安装蜜网网关虚拟机

# %% [markdown]
# 1. 使用准备好的镜像安装HoneyWall蜜网网关 roo-1.4.hw-20090425114542.iso，挂载流程如下图所示：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 设置 VMware Workstation 版本

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 选择稍后安装操作系统

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. 在这一步我们需要点击的是稍后安装系统，不是安装程序光盘映像文件。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 选择客户机操作系统。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. 设置蜜网网关虚拟机命名与路径

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. 设置蜜网网关虚拟硬件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 设置蜜网网关虚拟机内存大小，建议 1024M

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 设置网络连接方式，选择 NAT 模式，后面需另加两个网卡.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 设置虚拟硬盘接口类型，SCSI 接口选择为 LSI Logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 设置虚拟硬盘为 SCSI 硬盘

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4 创建虚拟硬盘

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 设置虚拟硬盘大小为 10G，无需立即分配全部空间

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 指定虚拟硬盘文件的绝对路径，注意必须给出全绝对路径，不要出现中文字

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 准备好创建虚拟机

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. 进入“自定义硬件”，添加两块网卡

# %% [markdown]
# 进行虚拟机设置，安装准备好的镜像文件，添加两个网络适配器，其中网络适配器2设置为仅主机模式，用于连接靶机网段，网络适配器3设置为自定义（VMnet8（NAT 模式）），用于连接攻击机网段：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 注意，必须移除打印机，否则会死机。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 到目前为止，开机前的步骤我们已经完成了。

# %% [markdown]
# ### 安装蜜网网关软件

# %% [markdown]
# 1. 开启虚拟机，进行HoneyWall的安装

# %% [markdown]
# 开机之后的样子是这样的，然后我们需要的就是点击任意键后的等待，安装过程也是全自动的，并且也会安装蜜网网关的默认环境。安装过程如下图：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 安装蜜网网关软件，键入回车键确认开始安装：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 蜜网网关软件安装完毕，进入登录界面

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 配置蜜网网关

# %% [markdown]
# 1. 登录蜜网网关

# %% [markdown]
# 使用用户名密码（`roo/honey` ）进行登录，然后使用 `su - ` 提升至root，进入配置界面（如果之后对配置进行修改，可以直接使用 `menu` 进入配置界面），缺省口令也为 honey

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 蜜网网关初始配置

# %% [markdown]
# 蜜网网关初始配置界面：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 如未进入此初始配置界面，则在 shell 中执行 menu

# %% [markdown]
# 3. 下面是对蜜网网关的设置的具体配置:

# %% [markdown]
# 蜜网网关配置菜单选项界面，选择 4 Honeywall Configuration 进行配置

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 对 The Honeynet Project 的不承担风险声明选择 Yes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. 选择 Defaults 配置方式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 接下来会 rebuid，稍等片刻.

# %% [markdown]
# ### 蜜罐信息配置

# %% [markdown]
# 进入蜜网网关配置界面(或命令行 menu)
#
# 1. 选择 4 HoneyWall Configuration
# 2. 选择 1 Mode and IP Information
# 3. 选择 2 Honeypot IP Address

# %% [markdown]
# Honeypot IP Address:设置蜜罐IP，即五个靶机的IP，这个地方添加的ip地址就是我们蜜罐主机的ip，多个蜜罐主机的ip地址需要用空格隔开。
#
# 192.168.13.130 192.168.13.131 192.168.13.132 192.168.13.133 192.168.13.134

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 注意： 蜜罐 IP 信息配置，空格分隔多个 IP 地址，目前 Roo 尚不支持蜜网网络中具有不同网段的蜜罐 IP 地址

# %% [markdown]
# 4. 选择 5 LAN Broadcast Address

# %% [markdown]
# LAN Broadcast Address：蜜罐网段的广播地址

# %% [markdown]
# 在这里我们填入的是蜜网所在网络的广播地址。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 选择 6 LAN CIDR Prefix

# %% [markdown]
# 蜜网网段配置，CIDR 格式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. 保存并退出到主菜单

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 蜜网网关管理配置

# %% [markdown]
# 蜜网网关配置主界面，
#
# 1. 选择 4 HoneyWall Configuration
#
# 2. 选择 2 Remote Management
#
# 3. 选择 1 Management IP

# %% [markdown]
# Management IP：用于管理HoneyWall的IP地址

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 4. 选择 2 Management Netmask

# %% [markdown]
# Management Netmask：管理IP地址的子网掩码

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 选择 3 Management Gateway

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. 选择 7 Manager，设置可以管理蜜网网关的远程控制端 IP 范围，以 CIDR 格式填写，可有多个 IP 网段，中间用空格分隔

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. 保存修改，退出上级菜单

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Sebek 服务器端配置

# %% [markdown]
# 蜜网网关配置主界面，
#
# 1. 选择 4 HoneyWall Configuratio
# 2. 选择 11 Sebek

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 目标端口选择为 1101，Sebek 数据包处理选项选择为 Drop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 至此，完成了配置。

# %% [markdown]
# # 环境测试

# %% [markdown]
# ## 测试蜜网网关的远程管理

# %% [markdown]
# Honeywall 上的防火墙设置不允许 icmp 协议访问管理口，同时会设置允许访问 ssh 和 https 的管理网段。下面测试 https 的远程管理：

# %% [markdown]
# 1. 测试 walleye 远程访问

# %% [markdown]
# 在 WinXPattacker （192.168.13.4） 这台虚拟机上访问 https://192.168.13.8 , 结果如下

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 出现一个修改密码的界面，按要求修改密码之后，进入如下Walleye 远程管理界面：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  连通性测试

# %% [markdown]
# 使用三台攻击机分别对两台靶机（蜜罐）进行ping命令操作，结果如图所示，连通性无误：

# %% [markdown]
# 这里，使用kali攻击机对五台靶机测试，其余攻击机，请同学们自行测试：

# %% [raw]
# ping 192.168.13.130
# ping 192.168.13.131
# ping 192.168.13.132
# ping 192.168.13.133
# ping 192.168.13.134

# %% [raw]
# root@kali:~# ping 192.168.13.130
# PING 192.168.13.130 (192.168.13.130) 56(84) bytes of data.
# 64 bytes from 192.168.13.130: icmp_seq=1 ttl=128 time=0.786 ms
# 64 bytes from 192.168.13.130: icmp_seq=2 ttl=128 time=0.652 ms
# 64 bytes from 192.168.13.130: icmp_seq=3 ttl=128 time=0.555 ms
#  64 bytes from 192.168.13.130: icmp_seq=4 ttl=128 time=0.633 ms
# ^C
# --- 192.168.13.130 ping statistics ---
# 4 packets transmitted, 4 received, 0% packet loss, time 3051ms
# rtt min/avg/max/mdev = 0.555/0.656/0.786/0.083 ms
# root@kali:~# ping 192.168.13.131
# PING 192.168.13.131 (192.168.13.131) 56(84) bytes of data.
# 64 bytes from 192.168.13.131: icmp_seq=1 ttl=128 time=0.699 ms
# 64 bytes from 192.168.13.131: icmp_seq=2 ttl=128 time=0.573 ms
# 64 bytes from 192.168.13.131: icmp_seq=3 ttl=128 time=0.595 ms
# ^C
# --- 192.168.13.131 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2025ms
# rtt min/avg/max/mdev = 0.573/0.622/0.699/0.054 ms
# root@kali:~# ping 192.168.13.132
# PING 192.168.13.132 (192.168.13.132) 56(84) bytes of data.
# 64 bytes from 192.168.13.132: icmp_seq=1 ttl=128 time=0.566 ms
# 64 bytes from 192.168.13.132: icmp_seq=2 ttl=128 time=0.496 ms
# 64 bytes from 192.168.13.132: icmp_seq=3 ttl=128 time=0.571 ms
# ^C
# --- 192.168.13.132 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2025ms
# rtt min/avg/max/mdev = 0.496/0.544/0.571/0.034 ms
# root@kali:~# ping 192.168.13.133
# PING 192.168.13.133 (192.168.13.133) 56(84) bytes of data.
# 64 bytes from 192.168.13.133: icmp_seq=1 ttl=128 time=0.582 ms
# 64 bytes from 192.168.13.133: icmp_seq=2 ttl=128 time=0.475 ms
# 64 bytes from 192.168.13.133: icmp_seq=3 ttl=128 time=0.604 ms
# ^C
# --- 192.168.13.133 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2041ms
# rtt min/avg/max/mdev = 0.475/0.553/0.604/0.056 ms
# root@kali:~# ping 192.168.13.134
# PING 192.168.13.134 (192.168.13.134) 56(84) bytes of data.
# 64 bytes from 192.168.13.134: icmp_seq=1 ttl=128 time=0.429 ms
# 64 bytes from 192.168.13.134: icmp_seq=2 ttl=128 time=0.437 ms
# 64 bytes from 192.168.13.134: icmp_seq=3 ttl=128 time=0.511 ms
# ^C
# --- 192.168.13.134 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2035ms
# rtt min/avg/max/mdev = 0.429/0.459/0.511/0.036 ms
# root@kali:~# ^C
# root@kali:~#
